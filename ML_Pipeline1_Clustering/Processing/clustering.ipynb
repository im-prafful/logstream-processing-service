# %%
import pandas as pd
from sqlalchemy import create_engine

DB_USER = "masterUser"
DB_PASS = "Admin$1234"
DB_NAME = "Logstream_DB"

# Since SSH tunnel is already active:
engine = create_engine(
    f"postgresql+psycopg2://{DB_USER}:{DB_PASS}@localhost:5433/{DB_NAME}"
)

# Read entire table into DataFrame
df = pd.read_sql("SELECT * FROM logs;", engine)

print(df.head())
# Out:
#    log_id                                app_id  \
# 0       1  9c23ec0a-006a-48f7-ab01-594493f93719
# 1       2  9c23ec0a-006a-48f7-ab01-594493f93719
# 2       3  9c23ec0a-006a-48f7-ab01-594493f93719
# 3       4  9c23ec0a-006a-48f7-ab01-594493f93719
# 4       5  9c23ec0a-006a-48f7-ab01-594493f93719
#
#                          timestamp        level  \
# 0 2025-11-04 19:50:04.551294+00:00  information
# 1 2025-11-04 19:50:04.649310+00:00        error
# 2 2025-11-04 19:50:04.691310+00:00        debug
# 3 2025-11-04 19:50:04.713320+00:00        error
# 4 2025-11-04 19:50:04.736274+00:00      warning
#
#                                              message            source  \
# 0                        User successfully logged in       api-backend
# 1  Transaction rollback triggered due to integrit...  shipping-service
# 2  Deserialized response from service "inventory-...   admin-dashboard
# 3  Email dispatch to "user@example.com" failed, a...   payment-service
# 4   Unverified email domain detected for user signup       api-backend
#
#                                          parsed_data pattern_id
# 0  {'method': 'DELETE', 'endpoint': '/v1/logs', '...       None
# 1  {'reason': 'address_not_found', 'status': 'del...       None
# 2  {'action': 'add_user', 'admin_id': 'adm_10', '...       None
# 3  {'status': 'refunded', 'gateway': 'paypal', 'u...       None
# 4  {'method': 'POST', 'endpoint': '/v1/auth/login...       None

# %%
df = df[["level", "message", "source", "parsed_data"]]
print(df.columns.tolist())
# Out:
# ['level', 'message', 'source', 'parsed_data']

# %%
from sentence_transformers import SentenceTransformer
import numpy as np

model=SentenceTransformer('all-MiniLM-L6-v2')

embeddings=np.vstack(df['message'].apply(lambda x:model.encode(x)))

print(embeddings.shape)
# Out:
# (91, 384)
